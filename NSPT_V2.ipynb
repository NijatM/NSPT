# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/ProGamerGov/neural-style-pt.git
# Out:
# Cloning into 'neural-style-pt'...
# remote: Enumerating objects: 497, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 497 (delta 0), reused 2 (delta 0), pack-reused 493
# Receiving objects: 100% (497/497), 36.25 MiB | 24.61 MiB/s, done.
# Resolving deltas: 100% (260/260), done.

# %%
# !cp -ri "/content/gdrive/My Drive/NSPT/checkpoints/channel_pruning.pth" /content/neural-style-pt/models/
# !cp -ri "/content/gdrive/My Drive/NSPT/checkpoints/nin_imagenet.pth" /content/neural-style-pt/models/
# !cp -ri "/content/gdrive/My Drive/NSPT/checkpoints/nyud-fcn32s-color-heavy.pth" /content/neural-style-pt/models/
# !cp -ri "/content/gdrive/My Drive/NSPT/checkpoints/vgg16-00b39a1b.pth" /content/neural-style-pt/models/
# !cp -ri "/content/gdrive/My Drive/NSPT/checkpoints/vgg19-d01eb7cb.pth" /content/neural-style-pt/models/

# %%
# !pip install torch==1.7.1+cu101 torchvision==0.8.2+cu101 torchaudio===0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 735.4MB 13kB/s
# ...
#      |████████████████████████████████| 12.8MB 146kB/s
# ...
#      |████████████████████████████████| 7.6MB 4.0MB/s
# ...
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.7.1+cu101 which is incompatible.
# ...
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
#   Found existing installation: torchvision 0.9.1+cu101
#     Uninstalling torchvision-0.9.1+cu101:
#       Successfully uninstalled torchvision-0.9.1+cu101
# ...

# %%
# !python neural-style-pt/neural_style.py -style_image '/content/gdrive/MyDrive/NSPT/style/style1' -style_weight 1000 -style_scale 1 -content_image '/content/gdrive/MyDrive/NSPT/input/input.png' -init random -learning_rate 1 -print_iter 50 -save_iter 250 -image_size 512 -num_iterations 1000 -model_file '/content/gdrive/MyDrive/NSPT/checkpoints/nyud-fcn32s-color-heavy.pth' -content_layers relu1_1,relu2_1,relu3_1,relu4_1,relu5_1 -style_layers relu1_1,relu2_1,relu3_1,relu4_1,relu5_1 -optimizer lbfgs -output_image '/content/gdrive/MyDrive/NSPT/output/A1.png' -tv_weight 0.00001 -original_colors 0 -backend cudnn 
# !python neural-style-pt/neural_style.py -style_image '/content/gdrive/MyDrive/NSPT/style/style1' -style_weight 1000 -style_scale 1 -content_image '/content/gdrive/MyDrive/NSPT/input/input.png' -content_weight 5 -init image -init_image '/content/gdrive/MyDrive/NSPT/output/A1.png' -print_iter 50 -save_iter 250 -image_size 768 -num_iterations 600 -model_file '/content/gdrive/MyDrive/NSPT/checkpoints/nyud-fcn32s-color-heavy.pth' -content_layers relu1_1,relu2_1,relu3_1,relu4_1,relu5_1 -style_layers relu1_1,relu2_1,relu3_1,relu4_1,relu5_1 -optimizer lbfgs -output_imag '/content/gdrive/MyDrive/NSPT/output/A2.png' -tv_weight 0 -gpu 0 -original_colors 0 -backend cudnn
# Out:
# VGG-16 Architecture Detected
# Using the fcn32s-heavy-pascal Model
# Successfully loaded /content/gdrive/MyDrive/NSPT/checkpoints/nyud-fcn32s-color-heavy.pth
# conv1_1: 64 3 3 3
# conv1_2: 64 64 3 3
# conv2_1: 128 64 3 3
# conv2_2: 128 128 3 3
# conv3_1: 256 128 3 3
# conv3_2: 256 256 3 3
# conv3_3: 256 256 3 3
# conv4_1: 512 256 3 3
# conv4_2: 512 512 3 3
# conv4_3: 512 512 3 3
# conv5_1: 512 512 3 3
# conv5_2: 512 512 3 3
# conv5_3: 512 512 3 3
# Setting up content layer 2: relu1_1
# Setting up style layer 2: relu1_1
# Setting up content layer 7: relu2_1
# Setting up style layer 7: relu2_1
# Setting up content layer 12: relu3_1
# Setting up style layer 12: relu3_1
# Setting up content layer 19: relu4_1
# Setting up style layer 19: relu4_1
# Setting up content layer 26: relu5_1
# Setting up style layer 26: relu5_1
# Capturing content targets
# nn.Sequential (
# ...
